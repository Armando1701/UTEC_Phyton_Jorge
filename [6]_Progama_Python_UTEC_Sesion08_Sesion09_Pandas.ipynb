# %% [markdown]
# <a href="https://colab.research.google.com/github/Armando1701/UTEC_Phyton_Jorge/blob/main/%5B6%5D_Progama_Python_UTEC_Sesion08_Sesion09_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pandas

# %% [markdown]
# ### Series

# %%
# Llamar a la librería Pandas
import pandas as pd

# %%
# Creación de una serie a partir de 5 números aleatorios usando la librería numpy
import numpy as np

pd.Series(np.random.randn(5))
# Out:
# 0    1.143049
# 1   -0.324795
# 2   -0.680803
# 3    0.297648
# 4    1.563421
# dtype: float64

# %%
pd.Series(np.random.randn(5), index=['a', 'b', 'c', 'd', 'e'])
# Out:
# a   -0.287761
# b    0.398317
# c   -0.981007
# d   -0.705496
# e   -0.426916
# dtype: float64

# %% [markdown]
# ### DataFrames

# %%
# Data Frames que provienen de diccionarios de series.
d = {
    'c1': pd.Series(['A', 'B', 'C']),
    'c2': pd.Series([1, 2., 3., 4.])
    }

print(d)

df = pd.DataFrame(d)
# Out:
# {'c1': 0    A
# 1    B
# 2    C
# dtype: object, 'c2': 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# dtype: float64}

# %%
df = pd.DataFrame(d)
df
# Out:
#     c1   c2
# 0    A  1.0
# 1    B  2.0
# 2    C  3.0
# 3  NaN  4.0

# %%
# Data Frames que provienen de diccionarios de listas.
d = {
    'c1': ['A', 'B', 'C', 'D'],
    'c2': [1, 2.0, 3.0, 4.0]
    }

df = pd.DataFrame(d)

# %%
df
# Out:
#   c1   c2
# 0  A  1.0
# 1  B  2.0
# 2  C  3.0
# 3  D  4.0

# %%
# Data Frames que provienen de diccionarios de series.

d = {
    'Item1': pd.DataFrame(np.random.randn(4, 3)),
    'Item2': pd.DataFrame(np.random.randn(4, 2))
    }

d
# Out:
# {'Item1':           0         1         2
#  0 -1.029686 -3.285654 -0.352564
#  1  1.217579  2.211036 -0.252169
#  2 -1.125165  0.438629 -0.621207
#  3  1.192992 -1.110127  0.012268,
#  'Item2':           0         1
#  0 -1.235287 -0.372956
#  1  0.952690 -0.627953
#  2  0.456600  0.732206
#  3 -0.622881 -1.926705}

# %%
pd.DataFrame(d['Item1'])
# Out:
#           0         1         2
# 0 -1.029686 -3.285654 -0.352564
# 1  1.217579  2.211036 -0.252169
# 2 -1.125165  0.438629 -0.621207
# 3  1.192992 -1.110127  0.012268

# %%
pd.DataFrame(d['Item2'])
# Out:
#           0         1
# 0 -1.235287 -0.372956
# 1  0.952690 -0.627953
# 2  0.456600  0.732206
# 3 -0.622881 -1.926705

# %% [markdown]
# ### Importar Datos CSV

# %%
from google.colab import drive
drive.mount('/gdrive')

# %%
ruta = "/gdrive/My Drive/[UTEC_2025]/[Programa_Python_Mayo]/ALUMNOS/"
dataset = "students.csv"

# %%
ruta+dataset

# %%
d = pd.read_csv(ruta+dataset)

# %%
#Leer los primeros registros.
d.head()

# %%
#Leer registros específicos de una variable
d[0:5]['REGION']

# %%
# Diccionario de datos
d = {
    'c1': pd.Series(['A', 'B', 'C']),
    'c2': pd.Series([1, 2., 3., 4.])
    }

df = pd.DataFrame(d)
df

# %%
ruta_out = "/gdrive/My Drive/[UTEC_2025]/[Programa_Python_Mayo]/ALUMNOS/out/"
df.to_csv(ruta_out+'sample_data.csv')

# %% [markdown]
# ### Importar Datos EXCEL

# %%
# Importar datos en formato xls.
dataset = 'students.xls'
d = pd.read_excel(ruta+dataset)
#Leer los primeros registros.
d.head()

# %%
#Leer registros específicos de una variable
df = d[0:5]['COUNTY']
df

# %%
#Exportar datos de un data frame a un xls
df.to_excel(ruta_out+'sample_data.xlsx')

# %% [markdown]
# ### Importar Datos JSON

# %%
import json

dataset = 'students.json'

json_data = open(ruta+dataset)
data = json.load(json_data)

# %%
data.keys()

# %%
data['meta']

# %%
data['data'][0]

# %% [markdown]
# ### Actividad N040

# %% [markdown]
# Leer el archivo de datos “dataset_train” y realice una vista previa de los datos.
